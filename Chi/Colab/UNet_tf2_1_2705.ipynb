# %% [markdown]
# <a href="https://colab.research.google.com/github/kongfupanda03/Prostate_cancer_capstone/blob/master/UNet_tf2_1_2705.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd drive/My\ Drive/Gleason-master
# Out:
# /content/drive/My Drive/Gleason-master

# %%
pwd
# Out:
# '/content/drive/My Drive/Gleason-master'

# %%
import os

# %%
import tensorflow as tf

# %%
print("Tensorflow version: ", tf.__version__)
# Out:
# Tensorflow version:  2.2.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow.keras.backend as K

# %%
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
# from tensorflow.keras.models import Model
# from tensorflow.keras.regularizers import l2
# from tensorflow.keras.layers import *
# %matplotlib inline
# import random
# # import re
# # from PIL import Image
# #from tensorflow.keras.engine import Layer
# from tensorflow.keras.applications.vgg16 import *
# from tensorflow.keras.models import *
# #from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
# import tensorflow.keras.backend as K
# # import tensorflow as tf
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
# from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
# # from tensorflow.compat.v1.layers import conv2d_transpose
# from tensorflow.layers import conv2d_transpose
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# from keras.utils import *

# %%
DATA_DIR = '/content/drive/My Drive/Gleason-master'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train_frames/train')
y_train_dir = os.path.join(DATA_DIR, 'train_masks/train')

x_valid_dir = os.path.join(DATA_DIR, 'val_frames/val')
y_valid_dir = os.path.join(DATA_DIR, 'val_masks/val')

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x

# %%
# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['0', '1', '2', '3', '4', '5']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
            with_shape_assert= False
    ):
        self.image_ids = os.listdir(images_dir)
        self.mask_ids = os.listdir(masks_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.image_ids]
        
        self.masks_fps =[]
        for i in self.image_ids:
            for j in self.mask_ids:
                if i[:-4] == j[0:16]:
                    self.masks_fps.append(os.path.join(masks_dir,j))
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
        self.with_shape_assert = with_shape_assert
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. 0 or 1 or 2)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        #this is to check the shape of image and ask after the agumentation and preprprocessing
        if self.with_shape_assert:
            assert image.shape ==(512, 512, 3)
            assert mask.shape ==(512,512,6)
            
        return image, mask
        
    def __len__(self):
        return len(self.image_ids)
    
    def allItemsToStr(self):
        result = "imgs are " + str(len(self.image_ids)) + " masks " + str(len(self.mask_ids))
        # for each img, result + img path/ name.../ size
        return result
    
    def __str__(self):
        return 'Dataset: len is: ' + str(len(self.image_ids)) + " item summary: " + self.allItemsToStr()

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['0','1','2','3','4','5'])

image, mask = dataset[0] # get some sample
visualize(
    image=image, 
    label_0=mask[..., 0].squeeze(),
    label_1=mask[..., 1].squeeze(),
    label_2=mask[..., 2].squeeze(),
    label_3=mask[..., 3].squeeze(),
    label_4=mask[..., 4].squeeze(),
    label_5=mask[..., 5].squeeze()
)

# %%
class Dataloader(tf.keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integer number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
        https://github.com/tensorflow/tensorflow/blob/v2.1.0/tensorflow/python/keras/utils/data_utils.py#L444-L454
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        # check batch shape
        assert len(batch)==2
        assert batch[0].shape ==(self.batch_size, 512, 512, 3)
        assert batch[1].shape ==(self.batch_size, 512, 512, 6)
        
        return batch[0], batch[1]
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)
    
    def dataToStr(self,data):
        return "img= " + str(data[0].shape) + " mask= " + str(data[1].shape)
    
    def allDataSetToStr(self):
        result = ''
        for data in self.dataset:
            result + ' ## ' + self.dataToStr(data)
        
        return result
    
    def __str__(self):
        return 'Data loader ' + str(len(self.indexes)) + " batch size " + str(self.batch_size) + " data set " + str(len(self.dataset)) + self.allDataSetToStr()

# %%
pip install -U albumentations>=0.3.0 --user

# %%
import albumentations as A

# %%
# define heavy augmentations
def get_training_augmentation():
    train_transform = [
        
        A.Resize(height=512, width=512, interpolation=cv2.INTER_NEAREST),

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        #A.PadIfNeeded(min_height=512, min_width=512, always_apply=True, border_mode=0),
        A.RandomCrop(height=512, width=512, always_apply=True),

        #A.IAAAdditiveGaussianNoise(p=0.2),
        #A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                #A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                #A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        # A.OneOf(
        #     [
        #         A.IAASharpen(p=1),
        #         A.Blur(blur_limit=3, p=1),
        #         A.MotionBlur(blur_limit=3, p=1),
        #     ],
        #     p=0.9,
        # ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.Resize(height=512, width=512, interpolation=cv2.INTER_NEAREST),
        #A.PadIfNeeded(512, 512)
    ]
    return A.Compose(test_transform)


def get_preprocessing():
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=normalize),
    ]
    return A.Compose(_transform)

def normalize(img, max_pixel_value=255.0, **args ):
    return img/255.0

# %%
# def normalize(img, max_pixel_value=255.0, **args ):
#     mean_img = img.mean()
#     std_img = img.std()
#     mean = np.array(mean_img, dtype=np.float32)
#     mean *= max_pixel_value

#     std = np.array(std_img, dtype=np.float32)
#     std *= max_pixel_value

#     denominator = np.reciprocal(std, dtype=np.float32)

#     img = img.astype(np.float32)
#     img -= mean
#     img *= denominator
#     return img

# %%
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 3

# batch_shape=(512,512,3)
# inputs = Input(batch_shape=(4, 512, 512, 3))
#Build the model
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
#s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(6, (1, 1), activation='softmax')(c9)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])

# %%
# define optomizer
optim = tf.keras.optimizers.Adam()

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %%
loss= tf.keras.losses.CategoricalCrossentropy()

# %%
smooth = 1.

# %%
model.compile(optim, loss, metrics=[dice_coef,'accuracy'])

# %%
#model.compile(optim, metrics, loss)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 16) 448         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512, 512, 16) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 512, 512, 16) 2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 32) 4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256, 256, 32) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 32) 9248        dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128, 128, 64) 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 36928       dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 128)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 128)  147584      dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 256)  295168      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 256)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 256)  590080      dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_4[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 128)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 128)  147584      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128, 128, 64) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 64) 36928       dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 256, 256, 32) 8224        conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_6[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 256, 256, 32) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 32) 9248        dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 512, 512, 16) 2064        conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 512, 512, 16) 4624        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 512, 512, 16) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 512, 512, 16) 2320        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 512, 512, 6)  102         conv2d_36[0][0]
# ==================================================================================================
# Total params: 1,941,190
# Trainable params: 1,941,190
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 2
CLASSES = ['0', '1','2','3','4','5']
LR = 0.0001
EPOCHS = 40
n_classes = len(CLASSES)

# %% [markdown]
# **SET** **UP DATA FOR TRAINING**

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(),
    with_shape_assert= True,
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(),
    with_shape_assert= True,
)

train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloader(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 512, 512, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 512, 512, n_classes)

# %%
#visualize one pair of image and mask in the train_dataset

image, mask = train_dataset[0] # get some sample
visualize(
    image=image, 
    label_0=mask[..., 0].squeeze(),
    label_1=mask[..., 1].squeeze(),
    label_2=mask[..., 2].squeeze(),
    label_3=mask[..., 3].squeeze(),
    label_4=mask[..., 4].squeeze(),
    label_5=mask[..., 5].squeeze()
)

# %% [markdown]
# SANITY CHECK ON train_dataloader

# %%
# len_check = []

# shape_check =[]

# for i in train_dataloader:
#     if len(i)!=2:
#         len_check.append(i)
#     if i[0].shape !=(BATCH_SIZE,512,512,3) or i[1].shape !=(BATCH_SIZE,512,512,6):
#         shape_check.append(i)
# print(len_check)
# print(shape_check)

# %%
# len_check = [i for i in train_dataloader if len(i)!=2]

# shape_check =[i for i in train_dataloader if i[0].shape !=(BATCH_SIZE,512,512,3) or i[1].shape != (BATCH_SIZE, 512,512,6)]

# %% [markdown]
# SANITY CHECK on valid_dataloader

# %%
# for i in valid_dataloader:
#     if len(i)!=2:
#         len_check.append(i)
#     if i[0].shape !=(1,512,512,3) or i[1].shape !=(1,512,512,6):
#         shape_check.append(i)
# print(len_check)
# print(shape_check)

# %% [markdown]
# **Define model callback settings**

# %%
mc = ModelCheckpoint(mode='max', filepath='model_UNet_2705_checkpoint.h5', monitor='accuracy', save_best_only=True, save_weights_only=True, verbose=1)
es = EarlyStopping(mode='max', monitor='val_accuracy', patience=10, verbose=1)
callbacks = [mc, es]

# %%
no_of_training_images = 200
no_of_validation_images = 44

# %% [markdown]
# **Train and save the U-Net model**

# %%
results_2705 = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    validation_data=valid_dataloader, 
    callbacks=callbacks, 
    validation_steps=len(valid_dataloader),verbose=1)

model.save_weights("model_UNet_2705.h5", overwrite=True)
# Out:
# Epoch 1/40
# 100/100 [==============================] - ETA: 0s - loss: 1.2138 - dice_coef: 0.3906 - accuracy: 0.4090
# Epoch 00001: accuracy improved from -inf to 0.40902, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 1200s 12s/step - loss: 1.2138 - dice_coef: 0.3906 - accuracy: 0.4090 - val_loss: 1.2724 - val_dice_coef: 0.4774 - val_accuracy: 0.4544
# Epoch 2/40
# 100/100 [==============================] - ETA: 0s - loss: 1.0313 - dice_coef: 0.4430 - accuracy: 0.5598
# Epoch 00002: accuracy improved from 0.40902 to 0.55981, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 310s 3s/step - loss: 1.0313 - dice_coef: 0.4430 - accuracy: 0.5598 - val_loss: 1.0765 - val_dice_coef: 0.5848 - val_accuracy: 0.6325
# Epoch 3/40
# 100/100 [==============================] - ETA: 0s - loss: 0.9458 - dice_coef: 0.4868 - accuracy: 0.5966
# Epoch 00003: accuracy improved from 0.55981 to 0.59661, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 309s 3s/step - loss: 0.9458 - dice_coef: 0.4868 - accuracy: 0.5966 - val_loss: 0.9100 - val_dice_coef: 0.6981 - val_accuracy: 0.6351
# Epoch 4/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8999 - dice_coef: 0.5064 - accuracy: 0.6287
# Epoch 00004: accuracy improved from 0.59661 to 0.62867, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 308s 3s/step - loss: 0.8999 - dice_coef: 0.5064 - accuracy: 0.6287 - val_loss: 0.9321 - val_dice_coef: 0.6686 - val_accuracy: 0.6351
# Epoch 5/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8542 - dice_coef: 0.5206 - accuracy: 0.6395
# Epoch 00005: accuracy improved from 0.62867 to 0.63949, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 308s 3s/step - loss: 0.8542 - dice_coef: 0.5206 - accuracy: 0.6395 - val_loss: 0.9064 - val_dice_coef: 0.6807 - val_accuracy: 0.5650
# Epoch 6/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8870 - dice_coef: 0.5354 - accuracy: 0.6141
# Epoch 00006: accuracy did not improve from 0.63949
# 100/100 [==============================] - 307s 3s/step - loss: 0.8870 - dice_coef: 0.5354 - accuracy: 0.6141 - val_loss: 0.8823 - val_dice_coef: 0.6928 - val_accuracy: 0.6400
# Epoch 7/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8568 - dice_coef: 0.5309 - accuracy: 0.6250
# Epoch 00007: accuracy did not improve from 0.63949
# 100/100 [==============================] - 310s 3s/step - loss: 0.8568 - dice_coef: 0.5309 - accuracy: 0.6250 - val_loss: 0.8664 - val_dice_coef: 0.6989 - val_accuracy: 0.6417
# Epoch 8/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8097 - dice_coef: 0.5347 - accuracy: 0.6443
# Epoch 00008: accuracy improved from 0.63949 to 0.64426, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 319s 3s/step - loss: 0.8097 - dice_coef: 0.5347 - accuracy: 0.6443 - val_loss: 0.8295 - val_dice_coef: 0.7187 - val_accuracy: 0.6453
# Epoch 9/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7801 - dice_coef: 0.5376 - accuracy: 0.6613
# Epoch 00009: accuracy improved from 0.64426 to 0.66131, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 316s 3s/step - loss: 0.7801 - dice_coef: 0.5376 - accuracy: 0.6613 - val_loss: 0.8393 - val_dice_coef: 0.7165 - val_accuracy: 0.6456
# Epoch 10/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8103 - dice_coef: 0.5346 - accuracy: 0.6638
# Epoch 00010: accuracy improved from 0.66131 to 0.66376, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 316s 3s/step - loss: 0.8103 - dice_coef: 0.5346 - accuracy: 0.6638 - val_loss: 0.8477 - val_dice_coef: 0.7053 - val_accuracy: 0.6471
# Epoch 11/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7803 - dice_coef: 0.5495 - accuracy: 0.6621
# Epoch 00011: accuracy did not improve from 0.66376
# 100/100 [==============================] - 315s 3s/step - loss: 0.7803 - dice_coef: 0.5495 - accuracy: 0.6621 - val_loss: 0.8346 - val_dice_coef: 0.7165 - val_accuracy: 0.6439
# Epoch 12/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8550 - dice_coef: 0.5378 - accuracy: 0.6244
# Epoch 00012: accuracy did not improve from 0.66376
# 100/100 [==============================] - 317s 3s/step - loss: 0.8550 - dice_coef: 0.5378 - accuracy: 0.6244 - val_loss: 0.9286 - val_dice_coef: 0.6637 - val_accuracy: 0.6474
# Epoch 13/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8472 - dice_coef: 0.5639 - accuracy: 0.6380
# Epoch 00013: accuracy did not improve from 0.66376
# 100/100 [==============================] - 320s 3s/step - loss: 0.8472 - dice_coef: 0.5639 - accuracy: 0.6380 - val_loss: 0.8289 - val_dice_coef: 0.7174 - val_accuracy: 0.6450
# Epoch 14/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8056 - dice_coef: 0.5599 - accuracy: 0.6507
# Epoch 00014: accuracy did not improve from 0.66376
# 100/100 [==============================] - 320s 3s/step - loss: 0.8056 - dice_coef: 0.5599 - accuracy: 0.6507 - val_loss: 0.8299 - val_dice_coef: 0.7117 - val_accuracy: 0.6504
# Epoch 15/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8180 - dice_coef: 0.5563 - accuracy: 0.6181
# Epoch 00015: accuracy did not improve from 0.66376
# 100/100 [==============================] - 320s 3s/step - loss: 0.8180 - dice_coef: 0.5563 - accuracy: 0.6181 - val_loss: 0.8498 - val_dice_coef: 0.7067 - val_accuracy: 0.6477
# Epoch 16/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8026 - dice_coef: 0.5652 - accuracy: 0.6553
# Epoch 00016: accuracy did not improve from 0.66376
# 100/100 [==============================] - 316s 3s/step - loss: 0.8026 - dice_coef: 0.5652 - accuracy: 0.6553 - val_loss: 0.8606 - val_dice_coef: 0.6971 - val_accuracy: 0.6434
# Epoch 17/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7831 - dice_coef: 0.5625 - accuracy: 0.6560
# Epoch 00017: accuracy did not improve from 0.66376
# 100/100 [==============================] - 319s 3s/step - loss: 0.7831 - dice_coef: 0.5625 - accuracy: 0.6560 - val_loss: 0.9535 - val_dice_coef: 0.6505 - val_accuracy: 0.5987
# Epoch 18/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8805 - dice_coef: 0.5583 - accuracy: 0.6112
# Epoch 00018: accuracy did not improve from 0.66376
# 100/100 [==============================] - 317s 3s/step - loss: 0.8805 - dice_coef: 0.5583 - accuracy: 0.6112 - val_loss: 0.8364 - val_dice_coef: 0.7090 - val_accuracy: 0.6513
# Epoch 19/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7831 - dice_coef: 0.5657 - accuracy: 0.6618
# Epoch 00019: accuracy did not improve from 0.66376
# 100/100 [==============================] - 311s 3s/step - loss: 0.7831 - dice_coef: 0.5657 - accuracy: 0.6618 - val_loss: 0.8140 - val_dice_coef: 0.7226 - val_accuracy: 0.6519
# Epoch 20/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7746 - dice_coef: 0.5754 - accuracy: 0.6562
# Epoch 00020: accuracy did not improve from 0.66376
# 100/100 [==============================] - 310s 3s/step - loss: 0.7746 - dice_coef: 0.5754 - accuracy: 0.6562 - val_loss: 0.8163 - val_dice_coef: 0.7199 - val_accuracy: 0.6536
# Epoch 21/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7932 - dice_coef: 0.5710 - accuracy: 0.6403
# Epoch 00021: accuracy did not improve from 0.66376
# 100/100 [==============================] - 311s 3s/step - loss: 0.7932 - dice_coef: 0.5710 - accuracy: 0.6403 - val_loss: 0.7923 - val_dice_coef: 0.7299 - val_accuracy: 0.6576
# Epoch 22/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7606 - dice_coef: 0.5827 - accuracy: 0.6622
# Epoch 00022: accuracy did not improve from 0.66376
# 100/100 [==============================] - 311s 3s/step - loss: 0.7606 - dice_coef: 0.5827 - accuracy: 0.6622 - val_loss: 0.9052 - val_dice_coef: 0.6823 - val_accuracy: 0.5967
# Epoch 23/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7952 - dice_coef: 0.5586 - accuracy: 0.6583
# Epoch 00023: accuracy did not improve from 0.66376
# 100/100 [==============================] - 311s 3s/step - loss: 0.7952 - dice_coef: 0.5586 - accuracy: 0.6583 - val_loss: 0.8667 - val_dice_coef: 0.6914 - val_accuracy: 0.6375
# Epoch 24/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7990 - dice_coef: 0.5590 - accuracy: 0.6573
# Epoch 00024: accuracy did not improve from 0.66376
# 100/100 [==============================] - 311s 3s/step - loss: 0.7990 - dice_coef: 0.5590 - accuracy: 0.6573 - val_loss: 0.8260 - val_dice_coef: 0.7162 - val_accuracy: 0.6554
# Epoch 25/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8247 - dice_coef: 0.5653 - accuracy: 0.6328
# Epoch 00025: accuracy did not improve from 0.66376
# 100/100 [==============================] - 311s 3s/step - loss: 0.8247 - dice_coef: 0.5653 - accuracy: 0.6328 - val_loss: 0.8302 - val_dice_coef: 0.7127 - val_accuracy: 0.6466
# Epoch 26/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7522 - dice_coef: 0.5614 - accuracy: 0.6649
# Epoch 00026: accuracy improved from 0.66376 to 0.66486, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 313s 3s/step - loss: 0.7522 - dice_coef: 0.5614 - accuracy: 0.6649 - val_loss: 0.8196 - val_dice_coef: 0.7175 - val_accuracy: 0.6544
# Epoch 27/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8290 - dice_coef: 0.5795 - accuracy: 0.6343
# Epoch 00027: accuracy did not improve from 0.66486
# 100/100 [==============================] - 310s 3s/step - loss: 0.8290 - dice_coef: 0.5795 - accuracy: 0.6343 - val_loss: 0.7894 - val_dice_coef: 0.7305 - val_accuracy: 0.6540
# Epoch 28/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8432 - dice_coef: 0.5730 - accuracy: 0.6267
# Epoch 00028: accuracy did not improve from 0.66486
# 100/100 [==============================] - 311s 3s/step - loss: 0.8432 - dice_coef: 0.5730 - accuracy: 0.6267 - val_loss: 0.9750 - val_dice_coef: 0.6317 - val_accuracy: 0.6556
# Epoch 29/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8059 - dice_coef: 0.5427 - accuracy: 0.6357
# Epoch 00029: accuracy did not improve from 0.66486
# 100/100 [==============================] - 311s 3s/step - loss: 0.8059 - dice_coef: 0.5427 - accuracy: 0.6357 - val_loss: 0.8030 - val_dice_coef: 0.7230 - val_accuracy: 0.6503
# Epoch 30/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7990 - dice_coef: 0.5478 - accuracy: 0.6425
# Epoch 00030: accuracy did not improve from 0.66486
# 100/100 [==============================] - 312s 3s/step - loss: 0.7990 - dice_coef: 0.5478 - accuracy: 0.6425 - val_loss: 0.8019 - val_dice_coef: 0.7232 - val_accuracy: 0.6549
# Epoch 31/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7802 - dice_coef: 0.5573 - accuracy: 0.6475
# Epoch 00031: accuracy did not improve from 0.66486
# 100/100 [==============================] - 313s 3s/step - loss: 0.7802 - dice_coef: 0.5573 - accuracy: 0.6475 - val_loss: 0.8080 - val_dice_coef: 0.7199 - val_accuracy: 0.6581
# Epoch 32/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7610 - dice_coef: 0.5668 - accuracy: 0.6651
# Epoch 00032: accuracy improved from 0.66486 to 0.66512, saving model to model_UNet_2705_checkpoint.h5
# 100/100 [==============================] - 317s 3s/step - loss: 0.7610 - dice_coef: 0.5668 - accuracy: 0.6651 - val_loss: 0.8125 - val_dice_coef: 0.7178 - val_accuracy: 0.6603
# Epoch 33/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8259 - dice_coef: 0.5719 - accuracy: 0.6291
# Epoch 00033: accuracy did not improve from 0.66512
# 100/100 [==============================] - 312s 3s/step - loss: 0.8259 - dice_coef: 0.5719 - accuracy: 0.6291 - val_loss: 0.7823 - val_dice_coef: 0.7324 - val_accuracy: 0.6593
# Epoch 34/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7660 - dice_coef: 0.5880 - accuracy: 0.6519
# Epoch 00034: accuracy did not improve from 0.66512
# 100/100 [==============================] - 310s 3s/step - loss: 0.7660 - dice_coef: 0.5880 - accuracy: 0.6519 - val_loss: 0.8290 - val_dice_coef: 0.7195 - val_accuracy: 0.6534
# Epoch 35/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7573 - dice_coef: 0.5846 - accuracy: 0.6571
# Epoch 00035: accuracy did not improve from 0.66512
# 100/100 [==============================] - 310s 3s/step - loss: 0.7573 - dice_coef: 0.5846 - accuracy: 0.6571 - val_loss: 0.7766 - val_dice_coef: 0.7349 - val_accuracy: 0.6673
# Epoch 36/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8261 - dice_coef: 0.5722 - accuracy: 0.6326
# Epoch 00036: accuracy did not improve from 0.66512
# 100/100 [==============================] - 310s 3s/step - loss: 0.8261 - dice_coef: 0.5722 - accuracy: 0.6326 - val_loss: 0.8188 - val_dice_coef: 0.7165 - val_accuracy: 0.6487
# Epoch 37/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7778 - dice_coef: 0.5701 - accuracy: 0.6544
# Epoch 00037: accuracy did not improve from 0.66512
# 100/100 [==============================] - 311s 3s/step - loss: 0.7778 - dice_coef: 0.5701 - accuracy: 0.6544 - val_loss: 0.7870 - val_dice_coef: 0.7298 - val_accuracy: 0.6594
# Epoch 38/40
# 100/100 [==============================] - ETA: 0s - loss: 0.8043 - dice_coef: 0.5634 - accuracy: 0.6426
# Epoch 00038: accuracy did not improve from 0.66512
# 100/100 [==============================] - 310s 3s/step - loss: 0.8043 - dice_coef: 0.5634 - accuracy: 0.6426 - val_loss: 0.7804 - val_dice_coef: 0.7282 - val_accuracy: 0.6589
# Epoch 39/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7627 - dice_coef: 0.5800 - accuracy: 0.6650
# Epoch 00039: accuracy did not improve from 0.66512
# 100/100 [==============================] - 311s 3s/step - loss: 0.7627 - dice_coef: 0.5800 - accuracy: 0.6650 - val_loss: 0.8070 - val_dice_coef: 0.7200 - val_accuracy: 0.6551
# Epoch 40/40
# 100/100 [==============================] - ETA: 0s - loss: 0.7688 - dice_coef: 0.5612 - accuracy: 0.6531
# Epoch 00040: accuracy did not improve from 0.66512
# 100/100 [==============================] - 311s 3s/step - loss: 0.7688 - dice_coef: 0.5612 - accuracy: 0.6531 - val_loss: 0.8291 - val_dice_coef: 0.7104 - val_accuracy: 0.6297

# %%
results_2704 = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    validation_data=valid_dataloader, 
    callbacks=callbacks, 
    validation_steps=len(valid_dataloader),verbose=1
)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 1000s 10s/step - loss: 1.1759 - dice_coef: 0.4149 - accuracy: 0.4015 - val_loss: 1.1738 - val_dice_coef: 0.5378 - val_accuracy: 0.5351
# Epoch 2/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.9945 - dice_coef: 0.4896 - accuracy: 0.5678 - val_loss: 1.2007 - val_dice_coef: 0.5031 - val_accuracy: 0.5548
# Epoch 3/40
# 100/100 [==============================] - 288s 3s/step - loss: 0.9238 - dice_coef: 0.4879 - accuracy: 0.6079 - val_loss: 0.9444 - val_dice_coef: 0.6772 - val_accuracy: 0.6321
# Epoch 4/40
# 100/100 [==============================] - 286s 3s/step - loss: 0.9942 - dice_coef: 0.4650 - accuracy: 0.5714 - val_loss: 1.2638 - val_dice_coef: 0.4720 - val_accuracy: 0.6112
# Epoch 5/40
# 100/100 [==============================] - 285s 3s/step - loss: 0.9361 - dice_coef: 0.4408 - accuracy: 0.5852 - val_loss: 0.9874 - val_dice_coef: 0.6380 - val_accuracy: 0.6306
# Epoch 6/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.9067 - dice_coef: 0.4686 - accuracy: 0.6280 - val_loss: 0.9269 - val_dice_coef: 0.6808 - val_accuracy: 0.6310
# Epoch 7/40
# 100/100 [==============================] - 286s 3s/step - loss: 0.9101 - dice_coef: 0.4613 - accuracy: 0.6262 - val_loss: 0.9369 - val_dice_coef: 0.6706 - val_accuracy: 0.6310
# Epoch 8/40
# 100/100 [==============================] - 286s 3s/step - loss: 0.9388 - dice_coef: 0.4824 - accuracy: 0.6144 - val_loss: 0.9363 - val_dice_coef: 0.6697 - val_accuracy: 0.6319
# Epoch 9/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.8937 - dice_coef: 0.4827 - accuracy: 0.6236 - val_loss: 1.0197 - val_dice_coef: 0.6132 - val_accuracy: 0.6295
# Epoch 10/40
# 100/100 [==============================] - 290s 3s/step - loss: 0.9042 - dice_coef: 0.4640 - accuracy: 0.6207 - val_loss: 0.9382 - val_dice_coef: 0.6679 - val_accuracy: 0.6321
# Epoch 11/40
# 100/100 [==============================] - 286s 3s/step - loss: 0.8583 - dice_coef: 0.4805 - accuracy: 0.6391 - val_loss: 0.9288 - val_dice_coef: 0.6785 - val_accuracy: 0.6322
# Epoch 12/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.8523 - dice_coef: 0.4797 - accuracy: 0.6519 - val_loss: 0.9343 - val_dice_coef: 0.6716 - val_accuracy: 0.6335
# Epoch 13/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.8536 - dice_coef: 0.5026 - accuracy: 0.6469 - val_loss: 0.9429 - val_dice_coef: 0.6732 - val_accuracy: 0.6305
# Epoch 14/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.9116 - dice_coef: 0.4933 - accuracy: 0.6245 - val_loss: 0.9329 - val_dice_coef: 0.6673 - val_accuracy: 0.6321
# Epoch 15/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.8614 - dice_coef: 0.4790 - accuracy: 0.6371 - val_loss: 0.8813 - val_dice_coef: 0.7040 - val_accuracy: 0.6362
# Epoch 16/40
# 100/100 [==============================] - 285s 3s/step - loss: 0.8591 - dice_coef: 0.4997 - accuracy: 0.6346 - val_loss: 0.9718 - val_dice_coef: 0.6423 - val_accuracy: 0.6351
# Epoch 17/40
# 100/100 [==============================] - 293s 3s/step - loss: 0.8116 - dice_coef: 0.4893 - accuracy: 0.6542 - val_loss: 0.8796 - val_dice_coef: 0.6936 - val_accuracy: 0.6367
# Epoch 18/40
# 100/100 [==============================] - 288s 3s/step - loss: 0.8657 - dice_coef: 0.4999 - accuracy: 0.6488 - val_loss: 0.9239 - val_dice_coef: 0.6721 - val_accuracy: 0.6316
# Epoch 19/40
# 100/100 [==============================] - 292s 3s/step - loss: 0.8758 - dice_coef: 0.5213 - accuracy: 0.6238 - val_loss: 0.9102 - val_dice_coef: 0.6798 - val_accuracy: 0.6405
# Epoch 20/40
# 100/100 [==============================] - 294s 3s/step - loss: 0.8136 - dice_coef: 0.5127 - accuracy: 0.6677 - val_loss: 0.9173 - val_dice_coef: 0.6779 - val_accuracy: 0.6432
# Epoch 21/40
# 100/100 [==============================] - 289s 3s/step - loss: 0.8022 - dice_coef: 0.5114 - accuracy: 0.6569 - val_loss: 0.8746 - val_dice_coef: 0.6980 - val_accuracy: 0.6452
# Epoch 22/40
# 100/100 [==============================] - 289s 3s/step - loss: 0.8522 - dice_coef: 0.5138 - accuracy: 0.6331 - val_loss: 0.8466 - val_dice_coef: 0.7127 - val_accuracy: 0.6460
# Epoch 23/40
# 100/100 [==============================] - 294s 3s/step - loss: 0.8555 - dice_coef: 0.5118 - accuracy: 0.6393 - val_loss: 0.8854 - val_dice_coef: 0.6889 - val_accuracy: 0.6410
# Epoch 24/40
# 100/100 [==============================] - 305s 3s/step - loss: 0.8238 - dice_coef: 0.5088 - accuracy: 0.6394 - val_loss: 0.8462 - val_dice_coef: 0.7135 - val_accuracy: 0.6481
# Epoch 25/40
# 100/100 [==============================] - 298s 3s/step - loss: 0.8184 - dice_coef: 0.5134 - accuracy: 0.6407 - val_loss: 0.8677 - val_dice_coef: 0.7005 - val_accuracy: 0.6447
# Epoch 26/40
# 100/100 [==============================] - 298s 3s/step - loss: 0.8004 - dice_coef: 0.5133 - accuracy: 0.6566 - val_loss: 0.8638 - val_dice_coef: 0.6995 - val_accuracy: 0.6486
# Epoch 27/40
# 100/100 [==============================] - 292s 3s/step - loss: 0.8171 - dice_coef: 0.4967 - accuracy: 0.6562 - val_loss: 0.8550 - val_dice_coef: 0.7051 - val_accuracy: 0.6473
# Epoch 28/40
# 100/100 [==============================] - 288s 3s/step - loss: 0.8016 - dice_coef: 0.5204 - accuracy: 0.6576 - val_loss: 0.8365 - val_dice_coef: 0.7156 - val_accuracy: 0.6499
# Epoch 29/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.8045 - dice_coef: 0.5314 - accuracy: 0.6635 - val_loss: 0.8432 - val_dice_coef: 0.7086 - val_accuracy: 0.6503
# Epoch 30/40
# 100/100 [==============================] - 287s 3s/step - loss: 0.7760 - dice_coef: 0.5239 - accuracy: 0.6694 - val_loss: 0.8482 - val_dice_coef: 0.7103 - val_accuracy: 0.6464
# Epoch 31/40
# 100/100 [==============================] - 288s 3s/step - loss: 0.8207 - dice_coef: 0.5205 - accuracy: 0.6510 - val_loss: 0.8754 - val_dice_coef: 0.6912 - val_accuracy: 0.6511
# Epoch 32/40
# 100/100 [==============================] - 285s 3s/step - loss: 0.7869 - dice_coef: 0.5039 - accuracy: 0.6699 - val_loss: 0.8743 - val_dice_coef: 0.7007 - val_accuracy: 0.6393
# Epoch 33/40
# 100/100 [==============================] - 289s 3s/step - loss: 0.8099 - dice_coef: 0.5220 - accuracy: 0.6572 - val_loss: 0.8278 - val_dice_coef: 0.7184 - val_accuracy: 0.6475
# Epoch 34/40
# 100/100 [==============================] - 295s 3s/step - loss: 0.7636 - dice_coef: 0.5179 - accuracy: 0.6642 - val_loss: 0.8247 - val_dice_coef: 0.7219 - val_accuracy: 0.6481
# Epoch 35/40
# 100/100 [==============================] - 289s 3s/step - loss: 0.8094 - dice_coef: 0.5064 - accuracy: 0.6453 - val_loss: 0.8632 - val_dice_coef: 0.7024 - val_accuracy: 0.6494
# Epoch 36/40
# 100/100 [==============================] - 295s 3s/step - loss: 0.8282 - dice_coef: 0.5127 - accuracy: 0.6383 - val_loss: 0.8319 - val_dice_coef: 0.7136 - val_accuracy: 0.6495
# Epoch 37/40
# 100/100 [==============================] - 299s 3s/step - loss: 0.7482 - dice_coef: 0.5085 - accuracy: 0.6684 - val_loss: 0.8170 - val_dice_coef: 0.7242 - val_accuracy: 0.6531
# Epoch 38/40
# 100/100 [==============================] - 301s 3s/step - loss: 0.7669 - dice_coef: 0.5249 - accuracy: 0.6690 - val_loss: 0.8386 - val_dice_coef: 0.7100 - val_accuracy: 0.6519
# Epoch 39/40
# 100/100 [==============================] - 300s 3s/step - loss: 0.8098 - dice_coef: 0.5271 - accuracy: 0.6484 - val_loss: 0.8224 - val_dice_coef: 0.7193 - val_accuracy: 0.6503
# Epoch 40/40
# 100/100 [==============================] - 296s 3s/step - loss: 0.7694 - dice_coef: 0.5181 - accuracy: 0.6713 - val_loss: 0.8406 - val_dice_coef: 0.7107 - val_accuracy: 0.6486

# %% [markdown]
# **Model Evaluation**

# %%
# Get actual number of epochs model was trained for
N = len(results_2705.history['loss'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("Training Loss")
plt.plot(np.arange(0, N), results_2705.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), results_2705.history["val_loss"], label="val_loss")
plt.ylim(0, 1)

fig.add_subplot(1,2,2)
plt.title("Training Accuracy")
plt.plot(np.arange(0, N), results_2705.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, N), results_2705.history["val_accuracy"], label="val_accuracy")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
# load best weights
model.load_weights('model_UNet_2705_checkpoint.h5')

# %%
scores = model.evaluate(valid_dataloader)
# Out:
# 44/44 [==============================] - 183s 4s/step - loss: 0.8125 - dice_coef: 0.7178 - accuracy: 0.6603

# %%
print("Loss: {:.5}".format(scores[0]))
# Out:
# Loss: 0.81248

# %%
scores
# Out:
# [0.8124849796295166, 0.7177692651748657, 0.6603069305419922]

# %% [markdown]
# **Visualization of results on test dataset**

# %%
n = 5
ids = np.random.choice(np.arange(len(valid_dataset)), size=n)

for i in ids:
    
    image, gt_mask = valid_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image)
    
    visualize(
        image = denormalize(image.squeeze()),
        label_0=gt_mask[..., 0].squeeze(),
        label_1=gt_mask[..., 1].squeeze(),
        label_2=gt_mask[..., 2].squeeze(),
        label_3=gt_mask[..., 3].squeeze(),
        label_4=gt_mask[..., 4].squeeze(),
        label_5=gt_mask[..., 5].squeeze(),
        pr_0=pr_mask[..., 0].squeeze(),
        pr_1=pr_mask[..., 1].squeeze(),
        pr_2=pr_mask[..., 2].squeeze(),
        pr_3=pr_mask[..., 3].squeeze(),
        pr_4=pr_mask[..., 4].squeeze(),
        pr_5=pr_mask[..., 5].squeeze()
    )

# %%
#function to display the images

def display_img(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']
  plt.figure(figsize=(16, 5))
  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

# %%
n = 5
ids = np.random.choice(np.arange(len(valid_dataset)), size=n)

for i in ids:
    
    image, gt_mask = valid_dataset[i]
    transformed_image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(transformed_image)
   
    #transform the ground truth mask to perform visualization
    gt_mask = tf.argmax(gt_mask, axis=-1)
    gt_mask = gt_mask[..., tf.newaxis]

    #transform the predicted mask
    pr_mask = tf.argmax(pr_mask, axis=-1)
    pr_mask = pr_mask[..., tf.newaxis]
    pr_mask = pr_mask[0]
  
    #display the images
    display_img([image,gt_mask, pr_mask])
